# %% [markdown]
# ### Hand Wriritng Classification Using Decision Tree

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Export dataset

# %%
df = pd.read_csv("")
