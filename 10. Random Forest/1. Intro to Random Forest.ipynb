# %% [markdown]
# ### Introduction to Random Forest

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creating Data

# %%
from sklearn.datasets import make_classification
X,y = make_classification(n_features=5, n_redundant=0, n_informative=5,n_clusters_per_class=1)

# %% [markdown]
# ### Creating DataFrame

# %%
df = pd.DataFrame(X,columns=['col1','col2','col3','col4','col5'])
df['target'] = y
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -2.839029 -0.954749  0.726375 -2.767700  0.909950       1
# 1  0.288453 -3.251268  1.075773 -2.777780 -0.983351       0
# 2 -2.792256  1.833165 -3.919150  0.195985 -0.948526       1
# 3  0.240915 -1.097422  0.995319 -1.648988 -2.148879       0
# 4  0.785083 -1.420560  1.286782 -1.044939 -0.080493       0

# %%
print(df.shape)
# Out:
# (100, 6)

# %% [markdown]
# ### Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
bag = BaggingClassifier(max_features=2)
bag.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %% [markdown]
# ### Ploting Tree

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %% [markdown]
# ### Model Creation(Using Random Forest)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_features=2)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])
# Out:
# RandomForestClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[4])
plt.show()
